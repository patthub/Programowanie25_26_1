# %%
imie = input()
# Out:
# Patryk

# %%
imie
# Out:
# 'Patryk'

# %%
age = input("ile masz lat? ")
# Out:
# ile masz lat? 32

# %%
type(age)
# Out:
# str

# %%
age_int = int(age)

# %%
age_int
# Out:
# 32

# %%
type(age_int)
# Out:
# int

# %%
x_float = float(x)

# %%
x_float
# Out:
# 32.1

# %%
x_int = int(x_float)

# %%
float(x_int)
# Out:
# 32.0

# %%
x_int
# Out:
# 32

# %%
x = "32"

# %%
x.isdigit()
# Out:
# True

# %%
#klauzula If Else

# %%
if 12 < 10:
  print("12 jest mniejsze od 10")
elif 12 < 10:
  print("12 jest wieksze od 10")
elif 12 == 10:
  print("123123")
else:
  print("asdada")
# Out:
# asdada

# %%
haslo = "Patryk"

# %%
if len(haslo) > 8:
  print("Hasło jest ok")
else:
  print("Haslo nie spelnia wymagan")
# Out:
# Haslo nie spelnia wymagan

# %%
if 12 > 10 and 12 != 10 and 12 >= 10:
  print("git")
# Out:
# git

# %%
if 12 > 10 and 12 != 10 or 12 >= 10:
  print("git")
# Out:
# git

# %%
if 12 > 10:
  if 12 != 10:
    print("git")
elif 12 < 10:
  if 12 >= 10:
    print("aaa")
# Out:
# git

# %%
if:
  if:
  elif:
    if:
    else:
  else:
elif:
  if:
    if:
    elif:
  elif:
      if:
      else:
else:


if:
  if:
    if:
      if:
        if:
          if:
            if:
              if:
                if:
                  if:
